# %%
from nltk.metrics import *

# %%
reference = 'ENG BB BASMAH AL JM AL IY ST UDENT AI'.split()
reference
# Out:
# ['ENG', 'BB', 'BASMAH', 'AL', 'JM', 'AL', 'IY', 'ST', 'UDENT', 'AI']

# %%
test = 'ENG BB BASMAH AL JM AL IY ST UDENT AI'.split()
test
# Out:
# ['ENG', 'BB', 'BASMAH', 'AL', 'JM', 'AL', 'IY', 'ST', 'UDENT', 'AI']

# %%
accuracy(reference, test)
# Out:
# 1.0

# %%
precision(set(reference), set(test))
# Out:
# 1.0

# %%
recall(set(reference), set(test))
# Out:
# 1.0

# %%
f_measure(set(reference), set(test))
# Out:
# 1.0

# %%
edit_distance("rain","shine")
# Out:
# 3

# %%
edit_distance("rain","sain")
# Out:
# 1

# %%
edit_distance("raine","shine")
# Out:
# 2

# %%
s1 = set([1,2,3,4])
s2 = set([3,4,5])
binary_distance(s1,s2)
# Out:
# 1.0

# %%
s1 = set([1,2,3,4])
s2 = set([1,2,3,4])
binary_distance(s1,s2)
# Out:
# 0.0

# %%
reference, test = ['BAS', 'neg', 'BAS', 'neg', 'BAS', 'neg'], ['BAS', 'neg','BAS', 'BAS', 'neg','neg']
print (ConfusionMatrix(reference, test))
# Out:
#     | B n |
#     | A e |
#     | S g |
# ----+-----+
# BAS |<2>1 |
# neg | 1<2>|
# ----+-----+
# (row = reference; col = test)
